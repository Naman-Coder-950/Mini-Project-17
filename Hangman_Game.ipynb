# %% [markdown]
# <a href="https://colab.research.google.com/github/Naman-Coder-950/Mini-Project-17/blob/main/Hangman_Game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Randomly choose a word
chosen_word = random.choice(word_list)
word_length = len(chosen_word)
lives = len(stages) - 1

# Display setup
display = ['_' for _ in range(word_length)]
guessed_letters = []

print("Welcome to Hangman!")

# Game loop
end_of_game = False
while not end_of_game:
    guess = input("Guess a letter: ").lower()

    if guess in guessed_letters:
        print(f"You already guessed '{guess}'. Try another letter.")
        continue

    guessed_letters.append(guess)

    if guess in chosen_word:
        for position in range(word_length):
            if chosen_word[position] == guess:
                display[position] = guess
    else:
        print(f"'{guess}' is not in the word. You lose a life.")
        lives -= 1

    print(' '.join(display))
    print(stages[len(stages) - 1 - lives])

    if '_' not in display:
        end_of_game = True
        print("Congratulations! You guessed the word!")
    elif lives == 0:
        end_of_game = True
        print("You lost! The word was:", chosen_word)
# Out:
# Welcome to Hangman!
# Guess a letter: y
# 'y' is not in the word. You lose a life.
# _ _ _ _ _ _ _ _ _ _ _
#
#       +---+
#       |   |
#       O   |
#           |
#           |
#           |
# ...
#
# Guess a letter: p
# p _ _ _ _ _ _ _ _ _ _
#
#       +---+
#       |   |
#       O   |
#           |
#           |
#           |
# ...
#
# Guess a letter: r
# p r _ _ r _ _ _ _ _ _
#
#       +---+
#       |   |
#       O   |
#           |
#           |
#           |
# ...
#
# Guess a letter: o
# p r o _ r _ _ _ _ _ _
#
#       +---+
#       |   |
#       O   |
#           |
#           |
#           |
# ...
#
# Guess a letter: g
# p r o g r _ _ _ _ _ g
#
#       +---+
#       |   |
#       O   |
#           |
#           |
#           |
# ...
#
# Guess a letter: a
# p r o g r a _ _ _ _ g
#
#       +---+
#       |   |
#       O   |
#           |
#           |
#           |
# ...
#
# Guess a letter: m
# p r o g r a m m _ _ g
#
#       +---+
#       |   |
#       O   |
#           |
#           |
#           |
# ...
#
# ...
